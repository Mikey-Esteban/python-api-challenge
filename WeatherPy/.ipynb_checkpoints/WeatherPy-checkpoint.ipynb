# %% [markdown]
# # __WeatherPy__
#
# ---
#
# ###### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they help you think through the steps

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
import pandas as pd
import numpy as np
import requests 
import json
import time
import scipy
import scipy.stats
from scipy.stats import linregress

# Import API key
from config import api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output FILE (CSV)
output_data_file = '../output_data/cities.csv'

# Range of latitudes and longitues
lat_range = (-90,90)
lng_range = (-180,180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name.title()
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Inclue a print log of each city as it's being processed (with city number and city name)

# %%
# Set user url links
url_end = '&APPID=' + api_key
url_base = 'http://api.openweathermap.org/data/2.5/weather?q='

data = {}

#loop through cities, check to see if city not in weather API
print('Beginning Data Retrieval')
print('-------------------------')
counter = 0
for city in cities:
    print('Processing Record ' + str(counter) + '| ' + city)
    url = url_base + city + url_end
    response = requests.get(url).json()
    if response['cod'] == '404':
        print(response['message'].title() + '. Skipping...')
    else:
        data[counter] = response
    counter += 1
print('-------------------------')    
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 0| Vaini
# Processing Record 1| Buraydah
# Processing Record 2| Carnarvon
# Processing Record 3| Wajir
# Processing Record 4| Berehove
# Processing Record 5| Chapais
# Processing Record 6| Upernavik
# Processing Record 7| Rikitea
# Processing Record 8| Busselton
# Processing Record 9| Saint-Joseph
# Processing Record 10| Hithadhoo
# Processing Record 11| Coihaique
# Processing Record 12| Batemans Bay
# Processing Record 13| Longyearbyen
# Processing Record 14| La Ronge
# Processing Record 15| Havelock
# Processing Record 16| New Norfolk
# Processing Record 17| Belushya Guba
# City Not Found. Skipping...
# Processing Record 18| Vaitupu
# City Not Found. Skipping...
# Processing Record 19| Taian
# City Not Found. Skipping...
# Processing Record 20| Verkhniy Tagil
# Processing Record 21| Kropotkin
# Processing Record 22| Beyla
# Processing Record 23| Oxford
# Processing Record 24| Puerto Ayora
# Processing Record 25| Punta Arenas
# Processing Record 26| Hilo
# Processing Record 27| Guaruja
# Processing Record 28| Ngunguru
# Processing Record 29| Mys Shmidta
# City Not Found. Skipping...
# Processing Record 30| Mataura
# Processing Record 31| Eenhana
# Processing Record 32| Cape Town
# Processing Record 33| Nyurba
# Processing Record 34| Sur
# Processing Record 35| Laguna
# Processing Record 36| Stephenville
# Processing Record 37| Dzhusaly
# City Not Found. Skipping...
# Processing Record 38| Hobart
# Processing Record 39| Palana
# Processing Record 40| Ponta Do Sol
# Processing Record 41| Batagay-Alyta
# Processing Record 42| Aguimes
# Processing Record 43| Chicama
# Processing Record 44| Mlonggo
# Processing Record 45| Sinjah
# City Not Found. Skipping...
# Processing Record 46| Taolanaro
# City Not Found. Skipping...
# Processing Record 47| Baherden
# Processing Record 48| Bambanglipuro
# Processing Record 49| Usinsk
# Processing Record 50| Korla
# City Not Found. Skipping...
# Processing Record 51| Norman Wells
# Processing Record 52| Puerto Colombia
# Processing Record 53| Nata
# Processing Record 54| Ushuaia
# Processing Record 55| Esperance
# Processing Record 56| Nanortalik
# Processing Record 57| Bredasdorp
# Processing Record 58| Narsaq
# Processing Record 59| Tautira
# Processing Record 60| Clyde River
# Processing Record 61| Quesnel
# Processing Record 62| Berdigestyakh
# Processing Record 63| North Bend
# Processing Record 64| Jamestown
# Processing Record 65| Illoqqortoormiut
# City Not Found. Skipping...
# Processing Record 66| Fairbanks
# Processing Record 67| Luwuk
# Processing Record 68| Puro
# Processing Record 69| Marcona
# City Not Found. Skipping...
# Processing Record 70| Kodiak
# Processing Record 71| Torbay
# Processing Record 72| Atuona
# Processing Record 73| Asau
# City Not Found. Skipping...
# Processing Record 74| Codrington
# Processing Record 75| Albany
# Processing Record 76| Lorengau
# Processing Record 77| Auki
# Processing Record 78| Ulladulla
# Processing Record 79| Geraldton
# Processing Record 80| Qaanaaq
# Processing Record 81| Muros
# Processing Record 82| Hermanus
# Processing Record 83| Barrow
# Processing Record 84| Pisco
# Processing Record 85| Sorland
# Processing Record 86| Beira
# Processing Record 87| Witrivier
# City Not Found. Skipping...
# Processing Record 88| Khandyga
# Processing Record 89| Kapaa
# Processing Record 90| Pizhma
# Processing Record 91| Ndele
# City Not Found. Skipping...
# Processing Record 92| Dingle
# Processing Record 93| San Felipe
# Processing Record 94| Mokolo
# Processing Record 95| Aklavik
# Processing Record 96| Ca Mau
# Processing Record 97| Tunduru
# City Not Found. Skipping...
# Processing Record 98| Yellowknife
# Processing Record 99| Havoysund
# Processing Record 100| College
# Processing Record 101| Eirunepe
# Processing Record 102| Umm Lajj
# Processing Record 103| Avarua
# Processing Record 104| Presidencia Roque Saenz Pena
# Processing Record 105| Saskylakh
# Processing Record 106| Samusu
# City Not Found. Skipping...
# Processing Record 107| Mataram
# Processing Record 108| Ketchikan
# Processing Record 109| Vallenar
# Processing Record 110| Kaitangata
# Processing Record 111| Jakar
# Processing Record 112| Pacific Grove
# Processing Record 113| Sorata
# Processing Record 114| Mar Del Plata
# Processing Record 115| Northam
# Processing Record 116| Srednekolymsk
# Processing Record 117| Nome
# Processing Record 118| Khani
# Processing Record 119| Pravia
# Processing Record 120| Butaritari
# Processing Record 121| Hasaki
# Processing Record 122| Rio Gallegos
# Processing Record 123| Georgetown
# Processing Record 124| Nhulunbuy
# Processing Record 125| Ursulo Galvan
# Processing Record 126| Namatanai
# Processing Record 127| Port Alfred
# Processing Record 128| Adrar
# Processing Record 129| Bethel
# Processing Record 130| Santa Cruz De Tenerife
# Processing Record 131| Novopskov
# Processing Record 132| Lolua
# City Not Found. Skipping...
# Processing Record 133| San Marcos
# Processing Record 134| Attawapiskat
# City Not Found. Skipping...
# Processing Record 135| Cockburn Town
# Processing Record 136| Saint George
# Processing Record 137| Lebu
# Processing Record 138| Meulaboh
# Processing Record 139| Bachaquero
# Processing Record 140| Kavaratti
# Processing Record 141| Rio Branco
# Processing Record 142| Sentyabrskiy
# City Not Found. Skipping...
# Processing Record 143| Balfour
# Processing Record 144| Bautar
# Processing Record 145| Nalut
# Processing Record 146| Warqla
# City Not Found. Skipping...
# Processing Record 147| Nikolskoye
# Processing Record 148| Eldikan
# City Not Found. Skipping...
# Processing Record 149| Svetlogorsk
# Processing Record 150| Dikson
# Processing Record 151| Terra Santa
# Processing Record 152| Coquimbo
# Processing Record 153| Susanville
# Processing Record 154| Ukiah
# Processing Record 155| Leningradskiy
# Processing Record 156| Ancud
# Processing Record 157| Kavieng
# Processing Record 158| Campoverde
# Processing Record 159| Vestmanna
# Processing Record 160| Chokurdakh
# Processing Record 161| Saiha
# Processing Record 162| Sao Felix Do Xingu
# Processing Record 163| Luau
# Processing Record 164| Port Lincoln
# Processing Record 165| Kahului
# Processing Record 166| Anadyr
# Processing Record 167| Manzil Tamim
# City Not Found. Skipping...
# Processing Record 168| Toliary
# City Not Found. Skipping...
# Processing Record 169| Ribeira Grande
# Processing Record 170| Galgani
# City Not Found. Skipping...
# Processing Record 171| Svetlaya
# Processing Record 172| Kazalinsk
# City Not Found. Skipping...
# Processing Record 173| Bathsheba
# Processing Record 174| Bikin
# Processing Record 175| Ninove
# Processing Record 176| Bac Lieu
# City Not Found. Skipping...
# Processing Record 177| Christchurch
# Processing Record 178| Senanga
# Processing Record 179| Bluff
# Processing Record 180| San Patricio
# Processing Record 181| Severo-Kurilsk
# Processing Record 182| Khatanga
# Processing Record 183| Yar-Sale
# Processing Record 184| Flinders
# Processing Record 185| Ciudad Bolivar
# Processing Record 186| Muravlenko
# Processing Record 187| Doha
# Processing Record 188| Salalah
# Processing Record 189| Kadykchan
# City Not Found. Skipping...
# Processing Record 190| French Harbor
# Processing Record 191| Tarbes
# Processing Record 192| Wasilla
# Processing Record 193| Saint-Georges
# Processing Record 194| Skagen
# Processing Record 195| Ushtobe
# Processing Record 196| Boyolangu
# Processing Record 197| Thompson
# Processing Record 198| Hue
# Processing Record 199| Barentsburg
# City Not Found. Skipping...
# Processing Record 200| Awjilah
# Processing Record 201| Robertsport
# Processing Record 202| Zirandaro
# Processing Record 203| Kayerkan
# Processing Record 204| Axim
# Processing Record 205| Provideniya
# Processing Record 206| Ulaanbaatar
# Processing Record 207| Talnakh
# Processing Record 208| Castro
# Processing Record 209| Tuktoyaktuk
# Processing Record 210| Victoria
# Processing Record 211| Ughelli
# Processing Record 212| Saint-Augustin
# Processing Record 213| Fare
# Processing Record 214| Grindavik
# Processing Record 215| Quang Ngai
# Processing Record 216| Porto Novo
# Processing Record 217| Atambua
# Processing Record 218| Orissaare
# Processing Record 219| Tuatapere
# Processing Record 220| Saint-Philippe
# Processing Record 221| Port Elizabeth
# Processing Record 222| Amga
# Processing Record 223| Ballina
# Processing Record 224| Lompoc
# Processing Record 225| Tabiauea
# City Not Found. Skipping...
# Processing Record 226| Sao Filipe
# Processing Record 227| Saleaula
# City Not Found. Skipping...
# Processing Record 228| Pangnirtung
# Processing Record 229| Atar
# Processing Record 230| Sept-Iles
# Processing Record 231| Constitucion
# Processing Record 232| Praia
# Processing Record 233| Panguna
# Processing Record 234| Toamasina
# Processing Record 235| Cleethorpes
# Processing Record 236| Filotion
# Processing Record 237| Tasiilaq
# Processing Record 238| Kununurra
# Processing Record 239| Abeche
# Processing Record 240| Florida
# Processing Record 241| Maarianhamina
# City Not Found. Skipping...
# Processing Record 242| Tall Kayf
# Processing Record 243| Sioux Lookout
# Processing Record 244| Yulara
# Processing Record 245| Hovd
# Processing Record 246| Iquique
# Processing Record 247| East London
# Processing Record 248| Huejuquilla El Alto
# Processing Record 249| Annigeri
# Processing Record 250| Pevek
# Processing Record 251| Natal
# Processing Record 252| Grand River South East
# City Not Found. Skipping...
# Processing Record 253| Mahebourg
# Processing Record 254| Mackay
# Processing Record 255| Meyungs
# City Not Found. Skipping...
# Processing Record 256| Zachagansk
# City Not Found. Skipping...
# Processing Record 257| Linxia
# Processing Record 258| Acapulco
# Processing Record 259| Bambous Virieux
# Processing Record 260| Bilma
# Processing Record 261| Kargasok
# Processing Record 262| Henties Bay
# Processing Record 263| Portland
# Processing Record 264| Launceston
# Processing Record 265| Hay River
# Processing Record 266| Jieshi
# Processing Record 267| Nexo
# Processing Record 268| Muzhi
# Processing Record 269| Morehead
# Processing Record 270| Yekaterinovka
# Processing Record 271| Bonavista
# Processing Record 272| Praia Da Vitoria
# Processing Record 273| Ottappalam
# Processing Record 274| Puyang
# Processing Record 275| Nizwa
# Processing Record 276| Alofi
# Processing Record 277| Logstor
# Processing Record 278| Santa Isabel Do Rio Negro
# Processing Record 279| Sibu
# Processing Record 280| Santa Rosa
# Processing Record 281| Khonsa
# Processing Record 282| Airai
# Processing Record 283| Mandera
# Processing Record 284| Kharp
# Processing Record 285| Non Thai
# Processing Record 286| Serenje
# Processing Record 287| Tiznit
# Processing Record 288| Ruston
# Processing Record 289| Saravan
# Processing Record 290| Steamboat Springs
# Processing Record 291| Tura
# Processing Record 292| Gamboula
# Processing Record 293| Shasta Lake
# Processing Record 294| Beyneu
# Processing Record 295| Portage
# Processing Record 296| Chuy
# Processing Record 297| San Luis
# Processing Record 298| Malakal
# City Not Found. Skipping...
# Processing Record 299| Tecoanapa
# Processing Record 300| Zhanakorgan
# Processing Record 301| Pokhara
# Processing Record 302| Shadrinsk
# Processing Record 303| Ostrovnoy
# Processing Record 304| Rosetta
# Processing Record 305| San Quintin
# Processing Record 306| Komsomolskiy
# Processing Record 307| Wampusirpi
# City Not Found. Skipping...
# Processing Record 308| Bang Pakong
# Processing Record 309| Banda Aceh
# Processing Record 310| Marovoay
# Processing Record 311| Tawzar
# City Not Found. Skipping...
# Processing Record 312| Lagoa
# Processing Record 313| Rocha
# Processing Record 314| Vestmannaeyjar
# Processing Record 315| Coahuayana
# Processing Record 316| Vardo
# Processing Record 317| Nizhneyansk
# City Not Found. Skipping...
# Processing Record 318| Berlevag
# Processing Record 319| Iqaluit
# Processing Record 320| Skagastrond
# City Not Found. Skipping...
# Processing Record 321| Monrovia
# Processing Record 322| Bandarbeyla
# Processing Record 323| Lubao
# Processing Record 324| Vao
# Processing Record 325| Husavik
# Processing Record 326| Bubaque
# Processing Record 327| Ternate
# Processing Record 328| Kandrian
# Processing Record 329| Souillac
# Processing Record 330| Port Hedland
# Processing Record 331| Kushmurun
# City Not Found. Skipping...
# Processing Record 332| Kuntaur
# Processing Record 333| Phnum Penh
# City Not Found. Skipping...
# Processing Record 334| Ligayan
# Processing Record 335| Nenjiang
# Processing Record 336| Aloleng
# Processing Record 337| Teguldet
# Processing Record 338| Naze
# Processing Record 339| Kruisfontein
# Processing Record 340| Hanstholm
# Processing Record 341| Camacha
# Processing Record 342| Baruun-Urt
# Processing Record 343| San Cristobal
# Processing Record 344| Tual
# Processing Record 345| Palic
# Processing Record 346| Sinnamary
# Processing Record 347| Riyadh
# Processing Record 348| Oranjemund
# Processing Record 349| Heyang
# Processing Record 350| Bhatkal
# Processing Record 351| Dalnerechensk
# Processing Record 352| Port Blair
# Processing Record 353| Sibolga
# Processing Record 354| Khudumelapye
# Processing Record 355| Upata
# Processing Record 356| Mogzon
# Processing Record 357| Palora
# Processing Record 358| Havre
# Processing Record 359| Vanimo
# Processing Record 360| Hohhot
# Processing Record 361| Norrtalje
# Processing Record 362| Yatou
# Processing Record 363| Sao Joao Da Barra
# Processing Record 364| Rajakhera
# Processing Record 365| Sakakah
# City Not Found. Skipping...
# Processing Record 366| Saldanha
# Processing Record 367| Wellington
# Processing Record 368| Nurota
# Processing Record 369| Araouane
# Processing Record 370| Liberia
# Processing Record 371| Adamas
# Processing Record 372| Sisimiut
# Processing Record 373| Neiafu
# Processing Record 374| Rundu
# Processing Record 375| Kampot
# Processing Record 376| Logumkloster
# Processing Record 377| General Roca
# Processing Record 378| Liverpool
# Processing Record 379| Cape Elizabeth
# City Not Found. Skipping...
# Processing Record 380| Quatre Cocos
# Processing Record 381| Banyumas
# Processing Record 382| Innisfail
# Processing Record 383| Maloy
# Processing Record 384| Caravelas
# Processing Record 385| Honningsvag
# Processing Record 386| Vila Velha
# Processing Record 387| Bud
# Processing Record 388| Eureka
# Processing Record 389| Bruchsal
# Processing Record 390| Rivers
# Processing Record 391| Najran
# Processing Record 392| Luderitz
# Processing Record 393| Sao Raimundo Nonato
# City Not Found. Skipping...
# Processing Record 394| Poysdorf
# Processing Record 395| Ust-Kuyga
# Processing Record 396| Ahipara
# Processing Record 397| Kursk
# Processing Record 398| Otradnoye
# Processing Record 399| Iskateley
# Processing Record 400| Altamira
# Processing Record 401| Chumikan
# Processing Record 402| Ixtapa
# Processing Record 403| Boone
# Processing Record 404| Rudnya
# Processing Record 405| Riacho De Santana
# Processing Record 406| Weligama
# Processing Record 407| Tikrit
# Processing Record 408| San Vicente
# Processing Record 409| Rome
# Processing Record 410| Salekhard
# Processing Record 411| Stantsiya Gorchakovo
# City Not Found. Skipping...
# Processing Record 412| Tessalit
# Processing Record 413| Olafsvik
# City Not Found. Skipping...
# Processing Record 414| Aquiraz
# Processing Record 415| Fort Smith
# Processing Record 416| Tiarei
# Processing Record 417| Grand Gaube
# Processing Record 418| Fulacunda
# City Not Found. Skipping...
# Processing Record 419| Ao Luk
# City Not Found. Skipping...
# Processing Record 420| Venado Tuerto
# Processing Record 421| Quelimane
# Processing Record 422| Tsihombe
# City Not Found. Skipping...
# Processing Record 423| Marzuq
# Processing Record 424| Rio De Janeiro
# Processing Record 425| Saint-Francois
# Processing Record 426| Amderma
# City Not Found. Skipping...
# Processing Record 427| Carballo
# Processing Record 428| Cuorgne
# Processing Record 429| Alta Floresta
# Processing Record 430| Cabo San Lucas
# Processing Record 431| Cherskiy
# Processing Record 432| Bengkulu
# City Not Found. Skipping...
# Processing Record 433| Waddan
# Processing Record 434| Gumdag
# Processing Record 435| Harper
# Processing Record 436| Saint-Gaudens
# Processing Record 437| Mahon
# Processing Record 438| Arraial Do Cabo
# Processing Record 439| Marsh Harbour
# Processing Record 440| Kars
# Processing Record 441| Hobyo
# Processing Record 442| Matamoros
# Processing Record 443| Mehamn
# Processing Record 444| Touros
# Processing Record 445| Olutanga
# Processing Record 446| Maragogi
# Processing Record 447| Quiroga
# Processing Record 448| Ler
# Processing Record 449| Sabancuy
# Processing Record 450| Porbandar
# Processing Record 451| Gurskoye
# City Not Found. Skipping...
# Processing Record 452| Faanui
# Processing Record 453| Gravelbourg
# Processing Record 454| Taloqan
# Processing Record 455| Rungata
# City Not Found. Skipping...
# Processing Record 456| Mafinga
# City Not Found. Skipping...
# Processing Record 457| Atbasar
# Processing Record 458| Magadan
# Processing Record 459| Shugurovo
# Processing Record 460| Mukhen
# Processing Record 461| Vieques
# Processing Record 462| Barpathar
# Processing Record 463| Qandala
# Processing Record 464| Palabuhanratu
# City Not Found. Skipping...
# Processing Record 465| Sechura
# Processing Record 466| Bucerias
# Processing Record 467| Cidreira
# Processing Record 468| Teya
# Processing Record 469| Keti Bandar
# Processing Record 470| Vila Franca Do Campo
# Processing Record 471| Nanakuli
# Processing Record 472| Harrisburg
# Processing Record 473| Kuandian
# Processing Record 474| Viedma
# Processing Record 475| Man
# Processing Record 476| Ewa Beach
# Processing Record 477| Foso
# Processing Record 478| Banjar
# Processing Record 479| Chagda
# City Not Found. Skipping...
# Processing Record 480| Baker City
# Processing Record 481| Los Llanos De Aridane
# Processing Record 482| Roald
# Processing Record 483| Samana
# Processing Record 484| Broome
# Processing Record 485| Sayyan
# Processing Record 486| Sao Desiderio
# Processing Record 487| Akdepe
# Processing Record 488| Mount Gambier
# Processing Record 489| Yataity
# Processing Record 490| Mayumba
# Processing Record 491| Podbrdo
# Processing Record 492| Jiayuguan
# Processing Record 493| Qasigiannguit
# Processing Record 494| Gimli
# Processing Record 495| Kinanah
# City Not Found. Skipping...
# Processing Record 496| Shingu
# Processing Record 497| Fredericksburg
# Processing Record 498| Sindor
# Processing Record 499| Borovnica
# Processing Record 500| Pervomayskiy
# Processing Record 501| Manadhoo
# Processing Record 502| Sola
# Processing Record 503| San Lazaro
# Processing Record 504| Sitka
# Processing Record 505| Jega
# Processing Record 506| Aksu
# Processing Record 507| Hofn
# Processing Record 508| Nguiu
# City Not Found. Skipping...
# Processing Record 509| Port-Gentil
# Processing Record 510| Emerald
# Processing Record 511| Evensk
# Processing Record 512| Nichinan
# Processing Record 513| Hami
# Processing Record 514| Arcata
# Processing Record 515| Ainazi
# Processing Record 516| Sehwan
# Processing Record 517| Seymchan
# Processing Record 518| Mersing
# Processing Record 519| Keffi
# Processing Record 520| Sefton
# Processing Record 521| Nizhniy Ingash
# Processing Record 522| Tiksi
# Processing Record 523| Salina Cruz
# Processing Record 524| Gat
# Processing Record 525| Burica
# City Not Found. Skipping...
# Processing Record 526| Falealupo
# City Not Found. Skipping...
# Processing Record 527| Wollongong
# Processing Record 528| Nefteyugansk
# Processing Record 529| Ornskoldsvik
# Processing Record 530| Uglegorsk
# Processing Record 531| Saint Anthony
# Processing Record 532| Malangali
# Processing Record 533| Dolbeau
# City Not Found. Skipping...
# Processing Record 534| Fortuna
# Processing Record 535| Pontes E Lacerda
# Processing Record 536| Labuhan
# Processing Record 537| Sangar
# Processing Record 538| Necochea
# Processing Record 539| Luwingu
# Processing Record 540| Chirilagua
# Processing Record 541| Molteno
# Processing Record 542| Poya
# Processing Record 543| Erenhot
# Processing Record 544| Otane
# Processing Record 545| Ust-Ishim
# Processing Record 546| Tala
# Processing Record 547| Ngukurr
# City Not Found. Skipping...
# Processing Record 548| Burnie
# Processing Record 549| Guerrero Negro
# Processing Record 550| Bocanda
# Processing Record 551| Cabedelo
# Processing Record 552| Abasha
# Processing Record 553| Mergui
# City Not Found. Skipping...
# Processing Record 554| Port-Cartier
# Processing Record 555| Boguchany
# Processing Record 556| Police
# Processing Record 557| San-Pedro
# Processing Record 558| Catuday
# Processing Record 559| Zabid
# Processing Record 560| Hit
# Processing Record 561| Tumannyy
# City Not Found. Skipping...
# Processing Record 562| Byron Bay
# Processing Record 563| Tigil
# Processing Record 564| Ankpa
# Processing Record 565| Madaba
# Processing Record 566| Katsuura
# Processing Record 567| Hambantota
# Processing Record 568| Curuguaty
# Processing Record 569| Waipawa
# Processing Record 570| Amapa
# Processing Record 571| Sobolevo
# Processing Record 572| Leh
# Processing Record 573| Brooks
# Processing Record 574| Hauterive
# Processing Record 575| Itagi
# Processing Record 576| Dom Pedrito
# Processing Record 577| Narasannapeta
# Processing Record 578| Nova Olimpia
# Processing Record 579| Mirnyy
# Processing Record 580| Zhigansk
# Processing Record 581| Taoudenni
# Processing Record 582| Bowen
# Processing Record 583| Aranos
# Processing Record 584| Sikeston
# Processing Record 585| Seoni Malwa
# Processing Record 586| Daru
# Processing Record 587| Saint-Fabien
# City Not Found. Skipping...
# Processing Record 588| Alyangula
# Processing Record 589| Birobidzhan
# Processing Record 590| Salinopolis
# Processing Record 591| Akyab
# City Not Found. Skipping...
# Processing Record 592| Rio Grande
# Processing Record 593| Florence
# Processing Record 594| Tulln
# Processing Record 595| La Asuncion
# Processing Record 596| Shelburne
# Processing Record 597| Ugoofaaru
# Processing Record 598| Buluang
# Processing Record 599| Bochil
# Processing Record 600| Grand Forks
# Processing Record 601| Minab
# Processing Record 602| Mount Isa
# Processing Record 603| Yenagoa
# Processing Record 604| Nadym
# Processing Record 605| Tolaga Bay
# Processing Record 606| Gigmoto
# Processing Record 607| Puerto Escondido
# Processing Record 608| Beringovskiy
# Processing Record 609| Te Anau
# Processing Record 610| Homer
# Processing Record 611| Port Hardy
# Processing Record 612| Peniche
# Processing Record 613| Belmonte
# Processing Record 614| Taburi
# City Not Found. Skipping...
# Processing Record 615| Shuyskoye
# Processing Record 616| Port Augusta
# Processing Record 617| Fort Saint James
# Processing Record 618| Camopi
# Processing Record 619| Hong Gai
# Processing Record 620| Half Moon Bay
# Processing Record 621| Campos Altos
# Processing Record 622| Senneterre
# Processing Record 623| North Branch
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# Data Munging to create Cities DF
cities_df = pd.DataFrame(data)
cities_df = cities_df.transpose()

# Extract values in certain columns
cities_df['clouds'] = cities_df['clouds'].apply(lambda x: x.get('all'))
cities_df['latitude'] = cities_df['coord'].apply(lambda x: x.get('lat'))
cities_df['longitude'] = cities_df['coord'].apply(lambda x: x.get('lon'))
cities_df['temp'] = cities_df['main'].apply(lambda x: x.get('temp'))
cities_df['country'] = cities_df['sys'].apply(lambda x: x.get('country'))
cities_df['date'] = cities_df['dt'].apply(lambda x: time.strftime("%D %H:%M", time.localtime(int(x))))
cities_df['humidity'] = cities_df['main'].apply(lambda x: x.get('humidity'))
cities_df['wind speed'] = cities_df['wind'].apply(lambda x: x.get('speed'))

# Change temp to Fahrenheit
cities_df['temp'] = cities_df['temp'].apply(lambda x: ((x - 273.15) * 9/5 + 32))
# Change column names
cities_df = cities_df.rename(columns={'name':'city', 'clouds':'cloudiness'})

# Data Munging to only keep wanted columns
cols = list(cities_df.columns.values)
cols = ['city','country','id','date','latitude','longitude','temp','cloudiness','wind speed','humidity']
cities_df = cities_df[cols]

cities_df.head()
# Out:
#         city country       id            date  latitude  longitude    temp  \
# 0      Vaini      IN  1273574  10/28/19 13:17     15.34      74.49  69.566
# 1   Buraydah      SA   107304  10/28/19 13:18     26.33      43.97  80.600
# 2  Carnarvon      ZA  1014034  10/28/19 13:16    -30.97      22.13  47.066
# 3      Wajir      KE   178443  10/28/19 13:18      1.75      40.07  84.200
# 4   Berehove      UA   712423  10/28/19 13:18     48.21      22.65  49.640
#
#    cloudiness  wind speed  humidity
# 0          85        1.26        92
# 1          20        7.20        74
# 2           0        9.83        39
# 3          32        4.96        70
# 4          75        2.10        87

# %% [markdown]
# ### Plotting the Data
# - Use proper labeling of the plots using plot titles (including date of analysis and axes labels.
# - Save the plotted figures as .pngs
# ---

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x = cities_df['latitude']
y = cities_df['temp']
date = cities_df.iloc[0]['date'].split(' ')[0]

# Plot
plt.scatter(x, y, color='navy', alpha=0.43)
plt.grid(True)
plt.title('City Latitude vs. Max Temperature ' + '(' + date + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.tight_layout()
# Save Figure
plt.savefig('../output_data/MaxTempvsLat.png')
# Show Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x = cities_df['latitude']
y = cities_df['humidity']
date = cities_df.iloc[0]['date'].split(' ')[0]

# Plot
plt.scatter(x, y, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Humidity ' + '(' + date + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Save Figure
plt.savefig('../output_data/HumidityvsLat.png')
# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x = cities_df['latitude']
y = cities_df['cloudiness']
date = cities_df.iloc[0]['date'].split(' ')[0]

# Plot
plt.scatter(x, y, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Cloudiness ' + '(' + date + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Save Figure
plt.savefig('../output_data/CloudinessvsLat.png')
# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed

# %%
x = cities_df['latitude']
y = cities_df['wind speed']
date = cities_df.iloc[0]['date'].split(' ')[0]

# Plot
plt.scatter(x, y, alpha=0.5)
plt.grid()
plt.title('City Latitude vs. Wind Speed ' + '(' + date + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Save Figure
plt.savefig('../output_data/WindSpeedvsLat.png')
# Show Plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_regress(x,y):
    vals = scipy.stats.linregress(x, y)
    return vals

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemi = cities_df.query('latitude > 0')
south_hemi = cities_df.query('latitude < 0')

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Collect graph values
x = north_hemi['latitude']
y = north_hemi['temp']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line, xy=(8,25), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: -0.6994101351746376

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Collect graph values
x = south_hemi['latitude']
y = south_hemi['temp']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line, xy=(-50,80), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: 0.4569694759808545

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Collect graph values
x = north_hemi['latitude']
y = north_hemi['humidity']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line, xy=(8,25), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: 0.027194150903290623

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Collect graph values
x = south_hemi['latitude']
y = south_hemi['humidity']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line, xy=(-50,150), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: 0.07636409064889396
# LinregressResult(slope=0.5395802379765728, intercept=80.71219610394054, rvalue=0.2763405338507074, pvalue=0.00028794925629306085, stderr=0.14564909942821827)

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Collect graph values
x = north_hemi['latitude']
y = north_hemi['cloudiness']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line, xy=(10,10), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: 0.02830393486939517

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Collect graph values
x = south_hemi['latitude']
y = south_hemi['cloudiness']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line, xy=(-50,10), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: 0.012057061622406986
# LinregressResult(slope=0.30416572788781693, intercept=50.21087208954755, rvalue=0.10980465209820113, pvalue=0.15651417329672532, stderr=0.21369847569658673)

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Collect graph values
x = north_hemi['latitude']
y = north_hemi['wind speed']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line, xy=(10,12), color='r', size=15)
# Show Plot
plt.plot()
# Out:
# The r-squared is: 0.03293674729790357
# []

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Collect graph values
x = south_hemi['latitude']
y = south_hemi['wind speed']

# Call linear regression function
vals = lin_regress(x,y)
# Collect r-squared
r_squared = vals[2]**2
# Collect slope
slope = vals[0]
# Collect y-intercept
intercept = vals[1]
# Collect line 
line = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Print r-squared val
if vals[2] < 0:
    sign = '-'
else:
    sign = ''
print('The r-squared is: '+ sign + str(vals[2]**2))
# Plot Graph
plt.figure(figsize=(8,6))
plt.plot(x, y, 'o', label='original data', alpha=.5)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line, xy=(-50,11), color='r', size=15)
# Show Plot
plt.show()
# Out:
# The r-squared is: -0.03488371403153117

# %%
save_file = cities_df.to_csv(output_data_file)

# %% [markdown]
# ## Observable Trends
# - Temperature is affected by latitude (closer to equator, greater temp)
# - Linear Regression trends were almost non existent for any Humidity/Wind Speed/Cloudiness for latitude on either Hemisphere
# - Largest spread of values among the value types is Cloudiness
